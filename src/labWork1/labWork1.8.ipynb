# %% [markdown]
# # LabWork 1.7

# %% [markdown]
# Necessary imports and configs

# %%
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

% matplotlib inline

# %% [markdown]
# Using delta function to show convolution as time shifting and multiplication as  sampling effect

# %%
# TODO finish implementation

# %% [markdown]
# Create triangle pulse. Make it periodical using dirac functions. Have at least 6 replications

# %%
t = np.linspace(0, 1, 5)
triangle = signal.sawtooth(2 * np.pi * 5 * t, 1)
plt.plot(t, triangle)
