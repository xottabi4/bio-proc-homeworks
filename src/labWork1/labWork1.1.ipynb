# %% [markdown]
# # LabWork 1.1

# %% [markdown]
# Necessary imports and configs

# %%
from __future__ import division

import matplotlib.pyplot as plt
import sounddevice as sd
import numpy as np

# %matplotlib inline

# %% [markdown]
# Reading voice signal and plot it

# %%
# default parameters
fs = 44100
sd.default.samplerate = fs
sd.default.channels = 2

duration = 5  # seconds
myrecording = sd.rec(int(duration * fs))

sd.wait()

plt.plot(myrecording)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb9017738d0>,
#  <matplotlib.lines.Line2D at 0x7fb901773a58>]

# %% [markdown]
# adding noise signal to it and playing it

# %%
noise = np.random.normal(0, 0.5, myrecording.shape)

sd.play(myrecording + noise)
plt.plot(myrecording + noise)
# Out:
# [<matplotlib.lines.Line2D at 0x7faf017d5198>,
#  <matplotlib.lines.Line2D at 0x7faf017d5320>]

# %%
sd.play(-myrecording)
plt.plot(-myrecording)
# Out:
# [<matplotlib.lines.Line2D at 0x7faf017910f0>,
#  <matplotlib.lines.Line2D at 0x7faf01791278>]
